# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mb
import seaborn as sns
import scipy.stats 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,classification_report

# %%
LData_url='/Users/srinivasaadvaith/Desktop/FINAL CODES/CODES/DATA_1.csv'
LData=pd.read_csv(LData_url)
LData.drop(['Unnamed: 0'],inplace=True,axis=1)
LData.head()
# Out:
#        Mean  Maximum_value  Minimum_value     Range  Standard Deviation  \
# 0  0.021097       1.548135      -1.476162  3.024297            0.298938
# 1  0.021229       1.362467      -1.394594  2.757061            0.277990
# 2  0.020257       1.572543      -1.220400  2.792943            0.295425
# 3  0.020035       1.432770      -1.398975  2.831745            0.268501
# 4  0.019870       1.271302      -1.161362  2.432664            0.286134
#
#    Variance  Absolute_mean  Absolute_MAX       RMS  Crest Factor  \
# 0  0.089364       0.203990      1.548135  0.299681      5.165940
# 1  0.077279       0.192230      1.394594  0.278800      5.002138
# 2  0.087276       0.202346      1.572543  0.296119      5.310510
# 3  0.072093       0.181403      1.432770  0.269247      5.321394
# 4  0.081873       0.196291      1.271302  0.286824      4.432349
#
#    Shape factor  Impulse Factor  Kurtosis  Skewness  Clearance Factor  \
# 0      1.469099        7.589278  4.553056 -0.097854          9.597586
# 1      1.450347        7.254836  4.696206 -0.014078          9.109635
# 2      1.463429        7.771555  3.735528 -0.073138          9.953077
# 3      1.484250        7.898281  5.582666  0.058976         10.071042
# 4      1.461213        6.476605  3.587559 -0.067984          8.281395
#
#                        FAULT TYPE   Label  Label_no
# 0  INNER RACE FAULT OF 0.007 INCH  IR_7_1         0
# 1  INNER RACE FAULT OF 0.007 INCH  IR_7_1         0
# 2  INNER RACE FAULT OF 0.007 INCH  IR_7_1         0
# 3  INNER RACE FAULT OF 0.007 INCH  IR_7_1         0
# 4  INNER RACE FAULT OF 0.007 INCH  IR_7_1         0

# %%
Data_modified=LData
del Data_modified['Label']
del Data_modified['FAULT TYPE']
Data_modified
# Out:
#           Mean  Maximum_value  Minimum_value     Range  Standard Deviation  \
# 0     0.021097       1.548135      -1.476162  3.024297            0.298938
# 1     0.021229       1.362467      -1.394594  2.757061            0.277990
# 2     0.020257       1.572543      -1.220400  2.792943            0.295425
# 3     0.020035       1.432770      -1.398975  2.831745            0.268501
# 4     0.019870       1.271302      -1.161362  2.432664            0.286134
# ...        ...            ...            ...       ...                 ...
# 2913  0.016535       0.166684      -0.167518  0.334202            0.059701
# 2914  0.017510       0.188588      -0.197559  0.386147            0.063149
# 2915  0.016256       0.317513      -0.345884  0.663397            0.074575
# 2916  0.015766       0.196307      -0.192761  0.389068            0.066686
# 2917  0.016396       0.181704      -0.184416  0.366120            0.064800
#
#       Variance  Absolute_mean  Absolute_MAX       RMS  Crest Factor  \
# 0     0.089364       0.203990      1.548135  0.299681      5.165940
# 1     0.077279       0.192230      1.394594  0.278800      5.002138
# 2     0.087276       0.202346      1.572543  0.296119      5.310510
# 3     0.072093       0.181403      1.432770  0.269247      5.321394
# 4     0.081873       0.196291      1.271302  0.286824      4.432349
# ...        ...            ...           ...       ...           ...
# 2913  0.003564       0.050273      0.167518  0.061948      2.704159
# 2914  0.003988       0.053922      0.197559  0.065532      3.014705
# 2915  0.005561       0.060085      0.345884  0.076326      4.531677
# 2916  0.004447       0.056439      0.196307  0.068524      2.864789
# 2917  0.004199       0.054171      0.184416  0.066842      2.758988
#
#       Shape factor  Impulse Factor  Kurtosis  Skewness  Clearance Factor  \
# 0         1.469099        7.589278  4.553056 -0.097854          9.597586
# 1         1.450347        7.254836  4.696206 -0.014078          9.109635
# 2         1.463429        7.771555  3.735528 -0.073138          9.953077
# 3         1.484250        7.898281  5.582666  0.058976         10.071042
# 4         1.461213        6.476605  3.587559 -0.067984          8.281395
# ...            ...             ...       ...       ...               ...
# 2913      1.232241        3.332175 -0.173194 -0.221345          3.904493
# 2914      1.215309        3.663797 -0.351542 -0.220355          4.252686
# 2915      1.270296        5.756570  0.970344 -0.270964          6.828517
# 2916      1.214125        3.478213 -0.334677 -0.280929          4.021315
# 2917      1.233902        3.404321 -0.170880 -0.169157          3.975248
#
#       Label_no
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2913         9
# 2914         9
# 2915         9
# 2916         9
# 2917         9
#
# [2918 rows x 16 columns]

# %%
scaler=StandardScaler()
scaler.fit(Data_modified.drop('Label_no',axis=1))
scaled_features=scaler.transform(Data_modified.drop('Label_no',axis=1))
scaled_features
# Out:
# array([[ 0.82485837,  0.02405314,  0.00533412, ...,  0.54760218,
#         -0.30198491,  0.45975117],
#        [ 0.84504647, -0.09696641,  0.05779303, ...,  0.58413499,
#          0.14424413,  0.34563565],
#        [ 0.69654245,  0.03996246,  0.16982165, ...,  0.33896318,
#         -0.1703385 ,  0.54288861],
#        ...,
#        [ 0.08568302, -0.77807535,  0.73224556, ..., -0.36673163,
#         -1.22405119, -0.18784183],
#        [ 0.01074414, -0.85707801,  0.83072342, ..., -0.69978231,
#         -1.27713417, -0.84435292],
#        [ 0.10705805, -0.8665964 ,  0.83609006, ..., -0.6579801 ,
#         -0.68177905, -0.85512639]])

# %%
scaled_df=pd.DataFrame(scaled_features,columns=Data_modified.columns[:-1])
scaled_df.head()
# Out:
#        Mean  Maximum_value  Minimum_value     Range  Standard Deviation  \
# 0  0.824858       0.024053       0.005334  0.009280           -0.136812
# 1  0.845046      -0.096966       0.057793 -0.077404           -0.204967
# 2  0.696542       0.039962       0.169822 -0.065765           -0.148240
# 3  0.662617      -0.051142       0.054976 -0.053178           -0.235841
# 4  0.637491      -0.156388       0.207791 -0.182628           -0.178468
#
#    Variance  Absolute_mean  Absolute_MAX       RMS  Crest Factor  \
# 0 -0.349796      -0.153395     -0.006532 -0.137100      0.922589
# 1 -0.384625      -0.214667     -0.103764 -0.205127      0.775526
# 2 -0.355812      -0.161959      0.008924 -0.148705      1.052384
# 3 -0.399571      -0.271077     -0.079588 -0.236247      1.062156
# 4 -0.371384      -0.193504     -0.181840 -0.178987      0.263968
#
#    Shape factor  Impulse Factor  Kurtosis  Skewness  Clearance Factor
# 0      0.409602        0.634400  0.547602 -0.301985          0.459751
# 1      0.317626        0.506575  0.584135  0.144244          0.345636
# 2      0.381791        0.704067  0.338963 -0.170338          0.542889
# 3      0.483917        0.752502  0.810366  0.533366          0.570477
# 4      0.370920        0.209134  0.301200 -0.142885          0.151938

# %%
X=scaled_df
Y=Data_modified['Label_no']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=750,stratify = Data_modified['Label_no'], random_state=132)

# %%
d_tree=DecisionTreeClassifier()

# %%
d_tree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions=d_tree.predict(X_test)

# %%
print(classification_report(Y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        75
#            1       1.00      1.00      1.00        75
#            2       0.97      0.97      0.97        75
#            3       0.97      0.95      0.96        75
#            4       0.88      0.96      0.92        75
#            5       0.80      0.87      0.83        75
#            6       1.00      0.99      0.99        75
#            7       0.84      0.72      0.78        75
#            8       0.96      0.97      0.97        75
#            9       1.00      1.00      1.00        75
#
#     accuracy                           0.94       750
#    macro avg       0.94      0.94      0.94       750
# weighted avg       0.94      0.94      0.94       750
